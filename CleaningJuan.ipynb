# %%
import numpy as np
import pandas as pd
import matplotlib

# %%
df = pd.read_csv('new/full.csv')
df.head()
# Out:
#    Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  propertyCode  \
# 0             0           0.0           0.0           0     100610812
# 1             1           1.0           1.0           1     101766825
# 2             2           2.0           2.0           2      98058039
# 3             3           3.0           3.0           3     102450094
# 4             4           4.0           4.0           4     100528636
#
#                                            thumbnail externalReference  \
# 0  https://img3.idealista.com/blur/WEB_LISTING/0/...              5644
# 1  https://img3.idealista.com/blur/WEB_LISTING/0/...          ACP1219A
# 2  https://img3.idealista.com/blur/WEB_LISTING/0/...          W-02OZM3
# 3  https://img3.idealista.com/blur/WEB_LISTING/0/...           nm00895
# 4  https://img3.idealista.com/blur/WEB_LISTING/0/...        3385-04514
#
#    numPhotos floor      price  ... has3DTour has360  hasStaging  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0.3', 'Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0',
#        'propertyCode', 'thumbnail', 'externalReference', 'numPhotos', 'floor',
#        'price', 'propertyType', 'operation', 'size', 'exterior', 'rooms',
#        'bathrooms', 'address', 'province', 'municipality', 'district',
#        'country', 'latitude', 'longitude', 'showAddress', 'url', 'distance',
#        'description', 'hasVideo', 'status', 'newDevelopment', 'hasLift',
#        'parkingSpace', 'priceByArea', 'detailedType', 'suggestedTexts',
#        'hasPlan', 'has3DTour', 'has360', 'hasStaging', 'highlight',
#        'superTopHighlight', 'topNewDevelopment', 'index', 'neighborhood',
#        'labels', 'newDevelopmentFinished'],
#       dtype='object')

# %%
df = df[['numPhotos', 'price', 'propertyType', 'size', 'exterior', 'rooms',
       'bathrooms', 'address', 'province', 'municipality', 'latitude', 'longitude',
       'status', 'newDevelopment', 'hasLift','parkingSpace', 'priceByArea', 'detailedType', 'suggestedTexts',
       'hasPlan', 'has3DTour', 'has360', 'hasStaging', 'highlight', 'neighborhood']]
df.head()
# Out:
#    numPhotos      price propertyType   size exterior  rooms  bathrooms  \
# 0         48   335000.0         flat  136.0     True      3          2
# 1         57  1650000.0         flat  179.0     True      2          3
# 2         26   770000.0         flat  109.0     True      2          2
# 3         36   175000.0         flat   49.0     True      1          1
# 4         46   280000.0         flat  121.0     True      4          2
#
#                          address province       municipality  ...  \
# 0                         SIGRID   Madrid  Rivas-Vaciamadrid  ...
# 1  Calle del Príncipe de Vergara   Madrid             Madrid  ...
# 2                   barrio Ibiza   Madrid             Madrid  ...
# 3       Calle de los Morales, 10   Madrid             Madrid  ...
# 4             Calle del Río Ulla   Madrid             Madrid  ...
#
#                                         parkingSpace  priceByArea  \
# 0  {'hasParkingSpace': True, 'isParkingSpaceInclu...       2463.0
# ...

# %%
list(df.columns)
# Out:
# ['numPhotos',
#  'price',
#  'propertyType',
#  'size',
#  'exterior',
#  'rooms',
#  'bathrooms',
#  'address',
#  'province',
#  'municipality',
#  'latitude',
#  'longitude',
#  'status',
#  'newDevelopment',
#  'hasLift',
#  'parkingSpace',
#  'priceByArea',
#  'detailedType',
#  'suggestedTexts',
#  'hasPlan',
#  'has3DTour',
#  'has360',
#  'hasStaging',
#  'highlight',
#  'neighborhood']

# %% [markdown]
# # Treatment of Missing Values

# %%
df.isna().sum()
# Out:
# numPhotos            0
# price                0
# propertyType         0
# size                 0
# exterior          1948
# rooms                0
# bathrooms            0
# address              0
# province             0
# municipality         0
# latitude             0
# longitude            0
# status               0
# newDevelopment       0
# hasLift           1777
# parkingSpace      3992
# priceByArea          0
# detailedType         0
# suggestedTexts       0
# hasPlan              0
# has3DTour            0
# has360               0
# hasStaging           0
# highlight         3980
# neighborhood      3396
# dtype: int64

# %% [markdown]
# ### Variable: Exterior

# %%
# is this a valid assumption (exterior.NaN = False)
df['exterior'] = df['exterior'].fillna(False)

# %% [markdown]
# ### Variable: hasLift

# %%
# is this a valid assumption (hasLift.NaN = False)
df['hasLift'] = df['hasLift'].fillna(False)

# %%
df['hasParkingSpace'] = np.where(
