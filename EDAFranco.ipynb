# %%
import pandas as pd

# %%
df = pd.read_csv('new/full.csv')
df
# Out:
#       Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  propertyCode  \
# 0                0           0.0           0.0           0     100610812
# 1                1           1.0           1.0           1     101766825
# 2                2           2.0           2.0           2      98058039
# 3                3           3.0           3.0           3     102450094
# 4                4           4.0           4.0           4     100528636
# ...            ...           ...           ...         ...           ...
# 6510           195           NaN           NaN         195     101494299
# 6511           196           NaN           NaN         196     102878198
# 6512           197           NaN           NaN         197      97684223
# 6513           198           NaN           NaN         198     102620357
# 6514           199           NaN           NaN         199     100726970
#
#                                               thumbnail externalReference  \
# 0     https://img3.idealista.com/blur/WEB_LISTING/0/...              5644
# 1     https://img3.idealista.com/blur/WEB_LISTING/0/...          ACP1219A
# 2     https://img3.idealista.com/blur/WEB_LISTING/0/...          W-02OZM3
# 3     https://img3.idealista.com/blur/WEB_LISTING/0/...           nm00895
# 4     https://img3.idealista.com/blur/WEB_LISTING/0/...        3385-04514
# ...                                                 ...               ...
# 6510  https://img3.idealista.com/blur/WEB_LISTING/0/...          W-02SDQA
# 6511  https://img3.idealista.com/blur/WEB_LISTING/0/...               NaN
# 6512  https://img3.idealista.com/blur/WEB_LISTING/0/...          73056985
# 6513  https://img3.idealista.com/blur/WEB_LISTING/0/...             MAYOR
# 6514  https://img3.idealista.com/blur/WEB_LISTING/0/...             MAYOR
#
#       numPhotos floor      price  ... has3DTour has360  hasStaging  \
# 0            48    bj   335000.0  ...     False  False        True
# 1            57     2  1650000.0  ...     False   True        True
# 2            26   NaN   770000.0  ...     False  False       False
# 3            36     1   175000.0  ...     False  False       False
# 4            46     2   280000.0  ...     False  False       False
# ...         ...   ...        ...  ...       ...    ...         ...
# 6510         27     1  2500000.0  ...     False  False       False
# 6511         22    bj    79000.0  ...     False  False       False
# 6512         13   NaN   126800.0  ...     False  False       False
# 6513         14   NaN   126100.0  ...     False  False       False
# 6514         14   NaN   126100.0  ...     False  False       False
#
#                               highlight  superTopHighlight  topNewDevelopment  \
# 0     {'groupDescription': 'Destacado'}              False              False
# 1     {'groupDescription': 'Destacado'}              False              False
# 2     {'groupDescription': 'Destacado'}              False              False
# 3     {'groupDescription': 'Destacado'}              False              False
# 4     {'groupDescription': 'Destacado'}              False              False
# ...                                 ...                ...                ...
# 6510                                NaN              False              False
# 6511                                NaN              False              False
# 6512                                NaN              False              False
# 6513                                NaN              False              False
# 6514                                NaN              False              False
#
#      index                     neighborhood  \
# 0      NaN                              NaN
# 1      NaN                              NaN
# 2      NaN                              NaN
# 3      NaN                              NaN
# 4      NaN                              NaN
# ...    ...                              ...
# 6510  20.0                       Castellana
# 6511  21.0  Ensanche de Vallecas - La Gavia
# 6512  22.0                              NaN
# 6513  23.0                              NaN
# 6514  24.0                              NaN
#
#                                         labels newDevelopmentFinished
# 0                                          NaN                    NaN
# 1                                          NaN                    NaN
# 2                                          NaN                    NaN
# 3                                          NaN                    NaN
# 4                                          NaN                    NaN
# ...                                        ...                    ...
# 6510  [{'name': 'luxuryType', 'text': 'Lujo'}]                    NaN
# 6511                                       NaN                    NaN
# 6512                                       NaN                    NaN
# 6513                                       NaN                    NaN
# 6514                                       NaN                    NaN
#
# [6515 rows x 46 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0.3', 'Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0',
#        'propertyCode', 'thumbnail', 'externalReference', 'numPhotos', 'floor',
#        'price', 'propertyType', 'operation', 'size', 'exterior', 'rooms',
#        'bathrooms', 'address', 'province', 'municipality', 'district',
#        'country', 'latitude', 'longitude', 'showAddress', 'url', 'distance',
#        'description', 'hasVideo', 'status', 'newDevelopment', 'hasLift',
#        'parkingSpace', 'priceByArea', 'detailedType', 'suggestedTexts',
#        'hasPlan', 'has3DTour', 'has360', 'hasStaging', 'highlight',
#        'superTopHighlight', 'topNewDevelopment', 'index', 'neighborhood',
#        'labels', 'newDevelopmentFinished'],
#       dtype='object')

# %%
df = df[['price', 'propertyType', 'size', 'exterior', 'rooms',
         'bathrooms', 'address', 'province', 'municipality',
         'latitude', 'longitude', 'status', 'newDevelopment', 'hasLift',
         'parkingSpace', 'priceByArea', 'detailedType', 'highlight']]

# %% [markdown]
# # Missing Values

# %%
df.isnull().sum()
# Out:
# price                0
# propertyType         0
# size                 0
# exterior          1948
# rooms                0
# bathrooms            0
# address              0
# province             0
# municipality         0
# latitude             0
# longitude            0
# status               0
# newDevelopment       0
# hasLift           1777
# parkingSpace      3992
# priceByArea          0
# detailedType         0
# highlight         3980
# dtype: int64

# %%
# Exterior cleaned
df['exterior'] = df['exterior'].fillna(False)
# Out:
# /var/folders/vs/d74l8bqd271fb7t3zg22mgs40000gn/T/ipykernel_80869/1317668624.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['exterior'] = df['exterior'].fillna(False)

# %%
# hasLift cleaned
df['hasLift'] = df['hasLift'].fillna(False)
# Out:
# /var/folders/vs/d74l8bqd271fb7t3zg22mgs40000gn/T/ipykernel_80869/538161793.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hasLift'] = df['hasLift'].fillna(False)

# %%
# highlight cleaned
df['highlight'] = df['highlight'].fillna("{'groupDescription': None}")
# Out:
# /var/folders/vs/d74l8bqd271fb7t3zg22mgs40000gn/T/ipykernel_80869/4113140830.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['highlight'] = df['highlight'].fillna("{'groupDescription': None}")

# %%
# parkingSpace cleaned
df['parkingSpace'] = df['parkingSpace'].fillna("{'hasParkingSpace': False, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': None}")
# Out:
# /var/folders/xs/s4fj4wdx6f7fkjpgcmjzz2lc0000gn/T/ipykernel_30069/1879921617.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['parkingSpace'] = df['parkingSpace'].fillna("{'hasParkingSpace': False, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': None}")

# %%
df.isnull().sum()
# Out:
# price             0
# propertyType      0
# size              0
# exterior          0
# rooms             0
# bathrooms         0
# address           0
# province          0
# municipality      0
# latitude          0
# longitude         0
# status            0
# newDevelopment    0
# hasLift           0
# parkingSpace      0
# priceByArea       0
# detailedType      0
# highlight         0
# dtype: int64

# %% [markdown]
# # Feature Engineering
# * parkingSpace included needs to be fixed
# * parkingSpace needs to be expanded
# * highlight needs to be expanded
# * detailedType needs to be expanded

# %%
# parkingSpace included fixed
df['parkingSpace'] = df['parkingSpace'].apply(lambda x: "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True, 'parkingSpacePrice': None}" if x == "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True}" else x)
# Out:
# /var/folders/xs/s4fj4wdx6f7fkjpgcmjzz2lc0000gn/T/ipykernel_30069/1422656108.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['parkingSpace'] = df['parkingSpace'].apply(lambda x: "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True, 'parkingSpacePrice': None}" if x == "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True}" else x)

# %%
# unique parkingSpaces are now consistent
df['parkingSpace'].unique()
# Out:
# array(["{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True, 'parkingSpacePrice': None}",
#        "{'hasParkingSpace': False, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': None}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 25000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 20000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 2000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 90000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 7500.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 60000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 5000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 37000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 17850.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 80000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 30000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 29000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 10000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 65000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 95000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 21000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 50000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 7000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 75.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 16000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 19000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 1.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 40000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 20.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 12000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 80.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 14000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 23000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 55000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 38000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 28000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 85000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 7250.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 29800.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 24000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 15000.0}"],
#       dtype=object)

# %%
df['detailedType'].unique()
# Out:
# array(["{'typology': 'flat'}",
#        "{'typology': 'flat', 'subTypology': 'duplex'}",
#        "{'typology': 'flat', 'subTypology': 'penthouse'}",
#        "{'typology': 'chalet'}",
#        "{'typology': 'chalet', 'subTypology': 'terracedHouse'}",
#        "{'typology': 'chalet', 'subTypology': 'independantHouse'}",
#        "{'typology': 'chalet', 'subTypology': 'semidetachedHouse'}",
#        "{'typology': 'countryHouse', 'subTypology': 'countryHouse'}",
#        "{'typology': 'countryHouse', 'subTypology': 'casaDePueblo'}",
#        "{'typology': 'flat', 'subTypology': 'studio'}",
#        "{'typology': 'countryHouse', 'subTypology': 'caseron'}",
#        "{'typology': 'countryHouse', 'subTypology': 'casale'}"],
#       dtype=object)

# %%
# fixing detailedType
df['detailedType'] = df['detailedType'].apply(lambda x: "{'typology': 'flat', 'subTypology': 'standardFlat'}" if x == "{'typology': 'flat'}" else x)
df['detailedType'] = df['detailedType'].apply(lambda x: "{'typology': 'chalet', 'subTypology': 'standardChalet'}" if x == "{'typology': 'chalet'}" else x)
# Out:
# /var/folders/vs/d74l8bqd271fb7t3zg22mgs40000gn/T/ipykernel_80869/1080788751.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['detailedType'] = df['detailedType'].apply(lambda x: "{'typology': 'flat', 'subTypology': 'standardFlat'}" if x == "{'typology': 'flat'}" else x)
# /var/folders/vs/d74l8bqd271fb7t3zg22mgs40000gn/T/ipykernel_80869/1080788751.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['detailedType'] = df['detailedType'].apply(lambda x: "{'typology': 'chalet', 'subTypology': 'standardChalet'}" if x == "{'typology': 'chalet'}" else x)

# %%
# detailedTypes are now consistent
df['detailedType'].unique()
# Out:
# array(["{'typology': 'flat', 'subTypology': 'standardFlat'}",
#        "{'typology': 'flat', 'subTypology': 'duplex'}",
#        "{'typology': 'flat', 'subTypology': 'penthouse'}",
#        "{'typology': 'chalet', 'subTypology': 'standardChalet'}",
#        "{'typology': 'chalet', 'subTypology': 'terracedHouse'}",
#        "{'typology': 'chalet', 'subTypology': 'independantHouse'}",
#        "{'typology': 'chalet', 'subTypology': 'semidetachedHouse'}",
#        "{'typology': 'countryHouse', 'subTypology': 'countryHouse'}",
#        "{'typology': 'countryHouse', 'subTypology': 'casaDePueblo'}",
#        "{'typology': 'flat', 'subTypology': 'studio'}",
#        "{'typology': 'countryHouse', 'subTypology': 'caseron'}",
#        "{'typology': 'countryHouse', 'subTypology': 'casale'}"],
#       dtype=object)

# %%
# Converting string of dicts --> dicts

from ast import literal_eval # Library for string evaluation

df['parkingSpace'] = df['parkingSpace'].apply(literal_eval)
df['highlight'] = df['highlight'].apply(literal_eval)
df['detailedType'] = df['detailedType'].apply(literal_eval)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 5
#       1 # Converting string of dicts --> dicts
#       3 from ast import literal_eval # Library for string evaluation
# ----> 5 df['parkingSpace'] = df['parkingSpace'].apply(literal_eval)
#       6 df['highlight'] = df['highlight'].apply(literal_eval)
#       7 df['detailedType'] = df['detailedType'].apply(literal_eval)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ast.py:110, in literal_eval(node_or_string)
#     108                 return left - right
#     109     return _convert_signed_num(node)
# --> 110 return _convert(node_or_string)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ast.py:109, in literal_eval.<locals>._convert(node)
#     107         else:
#     108             return left - right
# --> 109 return _convert_signed_num(node)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ast.py:83, in literal_eval.<locals>._convert_signed_num(node)
#      81     else:
#      82         return - operand
# ---> 83 return _convert_num(node)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ast.py:74, in literal_eval.<locals>._convert_num(node)
#      72 def _convert_num(node):
#      73     if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
# ---> 74         _raise_malformed_node(node)
#      75     return node.value
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ast.py:71, in literal_eval.<locals>._raise_malformed_node(node)
#      69 if lno := getattr(node, 'lineno', None):
#      70     msg += f' on line {lno}'
# ---> 71 raise ValueError(msg + f': {node!r}')
#
# ValueError: malformed node or string: nan

# %%
df = pd.concat([df,
           pd.json_normalize(df['parkingSpace']),
           pd.json_normalize(df['highlight']),
           pd.json_normalize(df['detailedType'])],
          axis = 1)

# %%
del df['parkingSpace']
del df['highlight']
del df['detailedType']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6515 entries, 0 to 6514
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   price                          6515 non-null   float64
#  1   propertyType                   6515 non-null   object
#  2   size                           6515 non-null   float64
#  3   exterior                       6515 non-null   bool
#  4   rooms                          6515 non-null   int64
#  5   bathrooms                      6515 non-null   int64
#  6   address                        6515 non-null   object
#  7   province                       6515 non-null   object
#  8   municipality                   6515 non-null   object
#  9   latitude                       6515 non-null   float64
#  10  longitude                      6515 non-null   float64
#  11  status                         6515 non-null   object
#  12  newDevelopment                 6515 non-null   bool
#  13  hasLift                        6515 non-null   bool
#  14  priceByArea                    6515 non-null   float64
#  15  hasParkingSpace                6515 non-null   bool
#  16  isParkingSpaceIncludedInPrice  6515 non-null   bool
#  17  parkingSpacePrice              198 non-null    float64
#  18  groupDescription               2535 non-null   object
#  19  typology                       6515 non-null   object
#  20  subTypology                    6515 non-null   object
# dtypes: bool(5), float64(6), int64(2), object(8)
# memory usage: 846.3+ KB

# %%
df
# Out:
#           price propertyType   size  exterior  rooms  bathrooms  \
# 0      335000.0         flat  136.0      True      3          2
# 1     1650000.0         flat  179.0      True      2          3
# 2      770000.0         flat  109.0      True      2          2
# 3      175000.0         flat   49.0      True      1          1
# 4      280000.0         flat  121.0      True      4          2
# ...         ...          ...    ...       ...    ...        ...
# 6510  2500000.0         flat  341.0      True      4          2
# 6511    79000.0         flat   66.0      True      1          1
# 6512   126800.0       chalet  159.0     False      3          3
# 6513   126100.0       chalet  150.0     False      3          2
# 6514   126100.0       chalet  150.0     False      3          3
#
#                               address province           municipality  \
# 0                              SIGRID   Madrid      Rivas-Vaciamadrid
# 1       Calle del Príncipe de Vergara   Madrid                 Madrid
# 2                        barrio Ibiza   Madrid                 Madrid
# 3            Calle de los Morales, 10   Madrid                 Madrid
# 4                  Calle del Río Ulla   Madrid                 Madrid
# ...                               ...      ...                    ...
# 6510                barrio Castellana   Madrid                 Madrid
# 6511   Calle de José Gutiérrez Maroto   Madrid                 Madrid
# 6512  Calle del Pintor Álvaro Delgado   Madrid  Olmeda de las Fuentes
# 6513                            MAYOR   Madrid  Olmeda de las Fuentes
# 6514                            MAYOR   Madrid  Olmeda de las Fuentes
#
#        latitude  longitude status  newDevelopment  hasLift  priceByArea
# 0     40.352160  -3.518342   good           False     True       2463.0
# 1     40.433593  -3.677788   good           False     True       9218.0
# 2     40.416551  -3.672922   good           False     True       7064.0
# 3     40.361994  -3.756360   good           False     True       3571.0
# 4     40.432982  -3.643371   good           False    False       2314.0
# ...         ...        ...    ...             ...      ...          ...
# 6510  40.433505  -3.681772   good           False     True       7331.0
# 6511  40.362047  -3.606132   good           False     True       1197.0
# 6512  40.369379  -3.218587   good           False    False        797.0
# 6513  40.371338  -3.221649   good           False    False        841.0
# 6514  40.370631  -3.221711   good           False    False        841.0
#
# [6515 rows x 15 columns]

# %%
df.to_csv('cleaned_df.csv')
