# %%
import pandas as pd

# %%
df = pd.read_csv('leganes.csv', index_col = 0)
df.shape
# Out:
# (1349, 43)

# %%
df = df[['price', 'propertyType', 'size', 'exterior', 'rooms',
         'bathrooms', 'address', 'province', 'municipality',
         'latitude', 'longitude', 'status', 'newDevelopment', 'hasLift',
         'parkingSpace', 'priceByArea', 'detailedType', 'highlight']]

# %%
df
# Out:
#          price propertyType   size exterior  rooms  bathrooms  \
# 0     138795.0         flat   72.0     True      3          1
# 1     117000.0         flat   59.0      NaN      2          1
# 2     154900.0         flat   52.0     True      1          1
# 3     291000.0         flat  151.0      NaN      3          3
# 4     310000.0         flat  129.0     True      3          2
# ...        ...          ...    ...      ...    ...        ...
# 1344  160000.0         flat   90.0     True      3          1
# 1345  220000.0         flat  101.0     True      3          2
# 1346  174900.0         flat  102.0     True      4          1
# 1347  219000.0         flat  109.0     True      4          2
# 1348  110500.0         flat   62.0     True      2          1
#
#                  address province municipality   latitude  longitude status  \
# 0        barrio Vírgenes   Madrid      Leganés  40.328098  -3.771660   good
# 1        barrio Vírgenes   Madrid      Leganés  40.327106  -3.771311   good
# 2        barrio Vírgenes   Madrid      Leganés  40.327852  -3.769317   good
# 3        Calle el Charco   Madrid      Leganés  40.329793  -3.769495   good
# 4                   Perú   Madrid      Leganés  40.330205  -3.770084   good
# ...                  ...      ...          ...        ...        ...    ...
# 1344       Paseo de Vigo   Madrid  Fuenlabrada  40.294182  -3.808867   good
# 1345    Calle Valladolid   Madrid     Alcorcón  40.341681  -3.827613   good
# 1346  barrio Buena Vista   Madrid       Madrid  40.370577  -3.749878   good
# 1347   Calle del Grafito   Madrid       Madrid  40.347064  -3.717380   good
# 1348    GOMEZ DE ARTECHE   Madrid       Madrid  40.371140  -3.751769   good
#
#       newDevelopment hasLift  \
# 0              False   False
# 1              False   False
# 2              False    True
# 3              False    True
# 4              False    True
# ...              ...     ...
# 1344           False    True
# 1345           False    True
# 1346           False   False
# 1347           False    True
# 1348           False   False
#
#                                            parkingSpace  priceByArea  \
# 0                                                   NaN       1928.0
# 1                                                   NaN       1983.0
# 2                                                   NaN       2979.0
# 3                                                   NaN       1927.0
# 4     {'hasParkingSpace': True, 'isParkingSpaceInclu...       2403.0
# ...                                                 ...          ...
# 1344  {'hasParkingSpace': True, 'isParkingSpaceInclu...       1778.0
# 1345                                                NaN       2178.0
# 1346                                                NaN       1715.0
# 1347  {'hasParkingSpace': True, 'isParkingSpaceInclu...       2009.0
# 1348                                                NaN       1782.0
#
#               detailedType                          highlight
# 0     {'typology': 'flat'}                                NaN
# 1     {'typology': 'flat'}                                NaN
# 2     {'typology': 'flat'}                                NaN
# 3     {'typology': 'flat'}                                NaN
# 4     {'typology': 'flat'}  {'groupDescription': 'Destacado'}
# ...                    ...                                ...
# 1344  {'typology': 'flat'}                                NaN
# 1345  {'typology': 'flat'}                                NaN
# 1346  {'typology': 'flat'}                                NaN
# 1347  {'typology': 'flat'}  {'groupDescription': 'Destacado'}
# 1348  {'typology': 'flat'}                                NaN
#
# [1349 rows x 18 columns]

# %%
# Exterior cleaned
df['exterior'] = df['exterior'].fillna(False)

# %%
# hasLift cleaned
df['hasLift'] = df['hasLift'].fillna(False)

# %%
# highlight cleaned
df['highlight'] = df['highlight'].fillna("{'groupDescription': None}")

# %%
# parkingSpace cleaned
df['parkingSpace'] = df['parkingSpace'].fillna("{'hasParkingSpace': False, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': None}")

# %% [markdown]
# # Feature engineering

# %%
# parkingSpace included fixed
df['parkingSpace'] = df['parkingSpace'].apply(lambda x: "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True, 'parkingSpacePrice': None}" if x == "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True}" else x)

# %%
# unique parkingSpaces are now consistent
df['parkingSpace'].unique()
# Out:
# array(["{'hasParkingSpace': False, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': None}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True, 'parkingSpacePrice': None}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 15000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 5000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 4000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 12000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 16000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 13000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 6000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 11000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 5500.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 19000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 25000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 65.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 8000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 40000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 18000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 20000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 13500.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 21000.0}"],
#       dtype=object)

# %%
# fixing detailedType
df['detailedType'] = df['detailedType'].apply(lambda x: "{'typology': 'flat', 'subTypology': 'standardFlat'}" if x == "{'typology': 'flat'}" else x)
df['detailedType'] = df['detailedType'].apply(lambda x: "{'typology': 'chalet', 'subTypology': 'standardChalet'}" if x == "{'typology': 'chalet'}" else x)

# %%
# Converting string of dicts --> dicts

from ast import literal_eval # Library for string evaluation

df['parkingSpace'] = df['parkingSpace'].apply(literal_eval)
df['highlight'] = df['highlight'].apply(literal_eval)
df['detailedType'] = df['detailedType'].apply(literal_eval)

# %%
df = pd.concat([df,
           pd.json_normalize(df['parkingSpace']),
           pd.json_normalize(df['highlight']),
           pd.json_normalize(df['detailedType'])],
          axis = 1)

# %%
df
# Out:
#          price propertyType   size  exterior  rooms  bathrooms  \
# 0     138795.0         flat   72.0      True      3          1
# 1     117000.0         flat   59.0     False      2          1
# 2     154900.0         flat   52.0      True      1          1
# 3     291000.0         flat  151.0     False      3          3
# 4     310000.0         flat  129.0      True      3          2
# ...        ...          ...    ...       ...    ...        ...
# 1344  160000.0         flat   90.0      True      3          1
# 1345  220000.0         flat  101.0      True      3          2
# 1346  174900.0         flat  102.0      True      4          1
# 1347  219000.0         flat  109.0      True      4          2
# 1348  110500.0         flat   62.0      True      2          1
#
#                  address province municipality   latitude  ...  \
# 0        barrio Vírgenes   Madrid      Leganés  40.328098  ...
# 1        barrio Vírgenes   Madrid      Leganés  40.327106  ...
# 2        barrio Vírgenes   Madrid      Leganés  40.327852  ...
# 3        Calle el Charco   Madrid      Leganés  40.329793  ...
# 4                   Perú   Madrid      Leganés  40.330205  ...
# ...                  ...      ...          ...        ...  ...
# 1344       Paseo de Vigo   Madrid  Fuenlabrada  40.294182  ...
# 1345    Calle Valladolid   Madrid     Alcorcón  40.341681  ...
# 1346  barrio Buena Vista   Madrid       Madrid  40.370577  ...
# 1347   Calle del Grafito   Madrid       Madrid  40.347064  ...
# 1348    GOMEZ DE ARTECHE   Madrid       Madrid  40.371140  ...
#
#                                            parkingSpace priceByArea  \
# 0     {'hasParkingSpace': False, 'isParkingSpaceIncl...      1928.0
# 1     {'hasParkingSpace': False, 'isParkingSpaceIncl...      1983.0
# 2     {'hasParkingSpace': False, 'isParkingSpaceIncl...      2979.0
# 3     {'hasParkingSpace': False, 'isParkingSpaceIncl...      1927.0
# 4     {'hasParkingSpace': True, 'isParkingSpaceInclu...      2403.0
# ...                                                 ...         ...
# 1344  {'hasParkingSpace': True, 'isParkingSpaceInclu...      1778.0
# 1345  {'hasParkingSpace': False, 'isParkingSpaceIncl...      2178.0
# 1346  {'hasParkingSpace': False, 'isParkingSpaceIncl...      1715.0
# 1347  {'hasParkingSpace': True, 'isParkingSpaceInclu...      2009.0
# 1348  {'hasParkingSpace': False, 'isParkingSpaceIncl...      1782.0
#
#                                            detailedType  \
# 0     {'typology': 'flat', 'subTypology': 'standardF...
# 1     {'typology': 'flat', 'subTypology': 'standardF...
# 2     {'typology': 'flat', 'subTypology': 'standardF...
# 3     {'typology': 'flat', 'subTypology': 'standardF...
# 4     {'typology': 'flat', 'subTypology': 'standardF...
# ...                                                 ...
# 1344  {'typology': 'flat', 'subTypology': 'standardF...
# 1345  {'typology': 'flat', 'subTypology': 'standardF...
# 1346  {'typology': 'flat', 'subTypology': 'standardF...
# 1347  {'typology': 'flat', 'subTypology': 'standardF...
# 1348  {'typology': 'flat', 'subTypology': 'standardF...
#
#                               highlight hasParkingSpace  \
# 0            {'groupDescription': None}           False
# 1            {'groupDescription': None}           False
# 2            {'groupDescription': None}           False
# 3            {'groupDescription': None}           False
# 4     {'groupDescription': 'Destacado'}            True
# ...                                 ...             ...
# 1344         {'groupDescription': None}            True
# 1345         {'groupDescription': None}           False
# 1346         {'groupDescription': None}           False
# 1347  {'groupDescription': 'Destacado'}            True
# 1348         {'groupDescription': None}           False
#
#       isParkingSpaceIncludedInPrice parkingSpacePrice groupDescription  \
# 0                             False               NaN             None
# 1                             False               NaN             None
# 2                             False               NaN             None
# 3                             False               NaN             None
# 4                              True               NaN        Destacado
# ...                             ...               ...              ...
# 1344                           True               NaN             None
# 1345                          False               NaN             None
# 1346                          False               NaN             None
# 1347                           True               NaN        Destacado
# 1348                          False               NaN             None
#
#       typology   subTypology
# 0         flat  standardFlat
# 1         flat  standardFlat
# 2         flat  standardFlat
# 3         flat  standardFlat
# 4         flat  standardFlat
# ...        ...           ...
# 1344      flat  standardFlat
# 1345      flat  standardFlat
# 1346      flat  standardFlat
# 1347      flat  standardFlat
# 1348      flat  standardFlat
#
# [1349 rows x 24 columns]

# %%
del df['parkingSpace']
del df['highlight']
del df['detailedType']

# %%
df2 = df

# %%
df = pd.read_csv('recleaned_df.csv', index_col = 0)

# %%
df.columns == df2.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
combined = pd.concat([df, df2], axis = 0)
combined.shape
# Out:
# (10300, 21)

# %%
combined = combined.drop_duplicates()
combined
# Out:
#           price propertyType   size  exterior  rooms  bathrooms  \
# 0      335000.0         flat  136.0      True      3          2
# 1     1650000.0         flat  179.0      True      2          3
# 2      770000.0         flat  109.0      True      2          2
# 3      175000.0         flat   49.0      True      1          1
# 4      280000.0         flat  121.0      True      4          2
# ...         ...          ...    ...       ...    ...        ...
# 1344   160000.0         flat   90.0      True      3          1
# 1345   220000.0         flat  101.0      True      3          2
# 1346   174900.0         flat  102.0      True      4          1
# 1347   219000.0         flat  109.0      True      4          2
# 1348   110500.0         flat   62.0      True      2          1
#
#                             address province       municipality   latitude  \
# 0                            SIGRID   Madrid  Rivas-Vaciamadrid  40.352160
# 1     Calle del Príncipe de Vergara   Madrid             Madrid  40.433593
# 2                      barrio Ibiza   Madrid             Madrid  40.416551
# 3          Calle de los Morales, 10   Madrid             Madrid  40.361994
# 4                Calle del Río Ulla   Madrid             Madrid  40.432982
# ...                             ...      ...                ...        ...
# 1344                  Paseo de Vigo   Madrid        Fuenlabrada  40.294182
# 1345               Calle Valladolid   Madrid           Alcorcón  40.341681
# 1346             barrio Buena Vista   Madrid             Madrid  40.370577
# 1347              Calle del Grafito   Madrid             Madrid  40.347064
# 1348               GOMEZ DE ARTECHE   Madrid             Madrid  40.371140
#
#       ...  status newDevelopment  hasLift  priceByArea  hasParkingSpace  \
# 0     ...    good          False     True       2463.0             True
# 1     ...    good          False     True       9218.0             True
# 2     ...    good          False     True       7064.0            False
# 3     ...    good          False     True       3571.0             True
# 4     ...    good          False    False       2314.0            False
# ...   ...     ...            ...      ...          ...              ...
# 1344  ...    good          False     True       1778.0             True
# 1345  ...    good          False     True       2178.0            False
# 1346  ...    good          False    False       1715.0            False
# 1347  ...    good          False     True       2009.0             True
# 1348  ...    good          False    False       1782.0            False
#
#       isParkingSpaceIncludedInPrice  parkingSpacePrice  groupDescription  \
# 0                              True                NaN         Destacado
# 1                              True                NaN         Destacado
# 2                             False                NaN         Destacado
# 3                             False            25000.0         Destacado
# 4                             False                NaN         Destacado
# ...                             ...                ...               ...
# 1344                           True                NaN              None
# 1345                          False                NaN              None
# 1346                          False                NaN              None
# 1347                           True                NaN         Destacado
# 1348                          False                NaN              None
#
#      typology   subTypology
# 0        flat  standardFlat
# 1        flat  standardFlat
# 2        flat  standardFlat
# 3        flat  standardFlat
# 4        flat  standardFlat
# ...       ...           ...
# 1344     flat  standardFlat
# 1345     flat  standardFlat
# 1346     flat  standardFlat
# 1347     flat  standardFlat
# 1348     flat  standardFlat
#
# [9869 rows x 21 columns]

# %%
combined.to_csv('recleaned_df.csv')

# %% [markdown]
# # Recleaned

# %%
combined
# Out:
#           price propertyType   size  exterior  rooms  bathrooms  \
# 0      335000.0         flat  136.0      True      3          2
# 1     1650000.0         flat  179.0      True      2          3
# 2      770000.0         flat  109.0      True      2          2
# 3      175000.0         flat   49.0      True      1          1
# 4      280000.0         flat  121.0      True      4          2
# ...         ...          ...    ...       ...    ...        ...
# 1344   160000.0         flat   90.0      True      3          1
# 1345   220000.0         flat  101.0      True      3          2
# 1346   174900.0         flat  102.0      True      4          1
# 1347   219000.0         flat  109.0      True      4          2
# 1348   110500.0         flat   62.0      True      2          1
#
#                             address province       municipality   latitude  \
# 0                            SIGRID   Madrid  Rivas-Vaciamadrid  40.352160
# 1     Calle del Príncipe de Vergara   Madrid             Madrid  40.433593
# 2                      barrio Ibiza   Madrid             Madrid  40.416551
# 3          Calle de los Morales, 10   Madrid             Madrid  40.361994
# 4                Calle del Río Ulla   Madrid             Madrid  40.432982
# ...                             ...      ...                ...        ...
# 1344                  Paseo de Vigo   Madrid        Fuenlabrada  40.294182
# 1345               Calle Valladolid   Madrid           Alcorcón  40.341681
# 1346             barrio Buena Vista   Madrid             Madrid  40.370577
# 1347              Calle del Grafito   Madrid             Madrid  40.347064
# 1348               GOMEZ DE ARTECHE   Madrid             Madrid  40.371140
#
#       ...  status newDevelopment  hasLift  priceByArea  hasParkingSpace  \
# 0     ...    good          False     True       2463.0             True
# 1     ...    good          False     True       9218.0             True
# 2     ...    good          False     True       7064.0            False
# 3     ...    good          False     True       3571.0             True
# 4     ...    good          False    False       2314.0            False
# ...   ...     ...            ...      ...          ...              ...
# 1344  ...    good          False     True       1778.0             True
# 1345  ...    good          False     True       2178.0            False
# 1346  ...    good          False    False       1715.0            False
# 1347  ...    good          False     True       2009.0             True
# 1348  ...    good          False    False       1782.0            False
#
#       isParkingSpaceIncludedInPrice  parkingSpacePrice  groupDescription  \
# 0                              True                NaN         Destacado
# 1                              True                NaN         Destacado
# 2                             False                NaN         Destacado
# 3                             False            25000.0         Destacado
# 4                             False                NaN         Destacado
# ...                             ...                ...               ...
# 1344                           True                NaN              None
# 1345                          False                NaN              None
# 1346                          False                NaN              None
# 1347                           True                NaN         Destacado
# 1348                          False                NaN              None
#
#      typology   subTypology
# 0        flat  standardFlat
# 1        flat  standardFlat
# 2        flat  standardFlat
# 3        flat  standardFlat
# 4        flat  standardFlat
# ...       ...           ...
# 1344     flat  standardFlat
# 1345     flat  standardFlat
# 1346     flat  standardFlat
# 1347     flat  standardFlat
# 1348     flat  standardFlat
#
# [9869 rows x 21 columns]
