# %%
import pandas as pd

# %%
df = pd.read_csv('new/full.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0.3', 'Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0',
#        'propertyCode', 'thumbnail', 'externalReference', 'numPhotos', 'floor',
#        'price', 'propertyType', 'operation', 'size', 'exterior', 'rooms',
#        'bathrooms', 'address', 'province', 'municipality', 'district',
#        'country', 'latitude', 'longitude', 'showAddress', 'url', 'distance',
#        'description', 'hasVideo', 'status', 'newDevelopment', 'hasLift',
#        'parkingSpace', 'priceByArea', 'detailedType', 'suggestedTexts',
#        'hasPlan', 'has3DTour', 'has360', 'hasStaging', 'highlight',
#        'superTopHighlight', 'topNewDevelopment', 'index', 'neighborhood',
#        'labels', 'newDevelopmentFinished'],
#       dtype='object')

# %%
df = df[[
       'numPhotos',
       'price', 'propertyType', 'size', 'exterior', 'rooms',
       'bathrooms', 'address', 'province', 'municipality', 'latitude', 'longitude', 
       'status', 'newDevelopment', 'hasLift',
       'parkingSpace', 'priceByArea', 'detailedType', 'suggestedTexts',
       'hasStaging', 'highlight',
       'neighborhood']]

# %%
df
# Out:
#       numPhotos floor      price propertyType   size exterior  rooms  \
# 0            48    bj   335000.0         flat  136.0     True      3
# 1            57     2  1650000.0         flat  179.0     True      2
# 2            26   NaN   770000.0         flat  109.0     True      2
# 3            36     1   175000.0         flat   49.0     True      1
# 4            46     2   280000.0         flat  121.0     True      4
# ...         ...   ...        ...          ...    ...      ...    ...
# 6510         27     1  2500000.0         flat  341.0     True      4
# 6511         22    bj    79000.0         flat   66.0     True      1
# 6512         13   NaN   126800.0       chalet  159.0      NaN      3
# 6513         14   NaN   126100.0       chalet  150.0      NaN      3
# 6514         14   NaN   126100.0       chalet  150.0      NaN      3
#
#       bathrooms                          address province  ... status  \
# 0             2                           SIGRID   Madrid  ...   good
# 1             3    Calle del Príncipe de Vergara   Madrid  ...   good
# 2             2                     barrio Ibiza   Madrid  ...   good
# 3             1         Calle de los Morales, 10   Madrid  ...   good
# 4             2               Calle del Río Ulla   Madrid  ...   good
# ...         ...                              ...      ...  ...    ...
# 6510          2                barrio Castellana   Madrid  ...   good
# 6511          1   Calle de José Gutiérrez Maroto   Madrid  ...   good
# 6512          3  Calle del Pintor Álvaro Delgado   Madrid  ...   good
# 6513          2                            MAYOR   Madrid  ...   good
# 6514          3                            MAYOR   Madrid  ...   good
#
#      newDevelopment  hasLift  \
# 0             False     True
# 1             False     True
# 2             False     True
# 3             False     True
# 4             False    False
# ...             ...      ...
# 6510          False     True
# 6511          False     True
# 6512          False      NaN
# 6513          False      NaN
# 6514          False      NaN
#
#                                            parkingSpace priceByArea  \
# 0     {'hasParkingSpace': True, 'isParkingSpaceInclu...      2463.0
# 1     {'hasParkingSpace': True, 'isParkingSpaceInclu...      9218.0
# 2                                                   NaN      7064.0
# 3     {'hasParkingSpace': True, 'isParkingSpaceInclu...      3571.0
# 4                                                   NaN      2314.0
# ...                                                 ...         ...
# 6510                                                NaN      7331.0
# 6511  {'hasParkingSpace': True, 'isParkingSpaceInclu...      1197.0
# 6512  {'hasParkingSpace': True, 'isParkingSpaceInclu...       797.0
# 6513                                                NaN       841.0
# 6514                                                NaN       841.0
#
#                                            detailedType  \
# 0                                  {'typology': 'flat'}
# 1                                  {'typology': 'flat'}
# 2                                  {'typology': 'flat'}
# 3                                  {'typology': 'flat'}
# 4                                  {'typology': 'flat'}
# ...                                                 ...
# 6510                               {'typology': 'flat'}
# 6511                               {'typology': 'flat'}
# 6512  {'typology': 'chalet', 'subTypology': 'terrace...
# 6513  {'typology': 'chalet', 'subTypology': 'terrace...
# 6514  {'typology': 'chalet', 'subTypology': 'terrace...
#
#                                          suggestedTexts hasStaging  \
# 0     {'subtitle': 'Rivas Centro, Rivas-Vaciamadrid'...       True
# 1     {'subtitle': 'Lista, Madrid', 'title': 'Piso e...       True
# 2        {'subtitle': 'Ibiza, Madrid', 'title': 'Piso'}      False
# 3     {'subtitle': 'Pau de Carabanchel, Madrid', 'ti...      False
# 4     {'subtitle': 'Pueblo Nuevo, Madrid', 'title': ...      False
# ...                                                 ...        ...
# 6510  {'subtitle': 'Castellana, Madrid', 'title': 'P...      False
# 6511  {'subtitle': 'Ensanche de Vallecas - La Gavia,...      False
# 6512  {'subtitle': 'Olmeda de las Fuentes', 'title':...      False
# 6513  {'subtitle': 'Olmeda de las Fuentes', 'title':...      False
# 6514  {'subtitle': 'Olmeda de las Fuentes', 'title':...      False
#
#                               highlight                     neighborhood
# 0     {'groupDescription': 'Destacado'}                              NaN
# 1     {'groupDescription': 'Destacado'}                              NaN
# 2     {'groupDescription': 'Destacado'}                              NaN
# 3     {'groupDescription': 'Destacado'}                              NaN
# 4     {'groupDescription': 'Destacado'}                              NaN
# ...                                 ...                              ...
# 6510                                NaN                       Castellana
# 6511                                NaN  Ensanche de Vallecas - La Gavia
# 6512                                NaN                              NaN
# 6513                                NaN                              NaN
# 6514                                NaN                              NaN
#
# [6515 rows x 24 columns]

# %%
### Missing Values

# %%
df.isnull().sum()
# Out:
# numPhotos            0
# price                0
# propertyType         0
# size                 0
# exterior             0
# rooms                0
# bathrooms            0
# address              0
# province             0
# municipality         0
# latitude             0
# longitude            0
# status               0
# newDevelopment       0
# hasLift           1777
# parkingSpace      3992
# priceByArea          0
# detailedType         0
# suggestedTexts       0
# hasStaging           0
# highlight         3980
# neighborhood      3396
# dtype: int64

# %%
df['exterior'] = df['exterior'].fillna(False)
# Out:
# /var/folders/71/6kdsbn2j2klcyp_x6_w6l51h0000gn/T/ipykernel_70654/92333966.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['exterior'] = df ['exterior'].fillna(False)

# %%
df['hasLift'] = df['hasLift'].fillna(False)
