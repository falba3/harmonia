# %%
import pandas as pd

# %%
df = pd.read_csv('new/full.csv')
df
# Out:
#       Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  propertyCode  \
# 0                0           0.0           0.0           0     100610812
# 1                1           1.0           1.0           1     101766825
# 2                2           2.0           2.0           2      98058039
# 3                3           3.0           3.0           3     102450094
# 4                4           4.0           4.0           4     100528636
# ...            ...           ...           ...         ...           ...
# 6510           195           NaN           NaN         195     101494299
# 6511           196           NaN           NaN         196     102878198
# 6512           197           NaN           NaN         197      97684223
# 6513           198           NaN           NaN         198     102620357
# 6514           199           NaN           NaN         199     100726970
#
#                                               thumbnail externalReference  \
# 0     https://img3.idealista.com/blur/WEB_LISTING/0/...              5644
# 1     https://img3.idealista.com/blur/WEB_LISTING/0/...          ACP1219A
# 2     https://img3.idealista.com/blur/WEB_LISTING/0/...          W-02OZM3
# 3     https://img3.idealista.com/blur/WEB_LISTING/0/...           nm00895
# 4     https://img3.idealista.com/blur/WEB_LISTING/0/...        3385-04514
# ...                                                 ...               ...
# 6510  https://img3.idealista.com/blur/WEB_LISTING/0/...          W-02SDQA
# 6511  https://img3.idealista.com/blur/WEB_LISTING/0/...               NaN
# 6512  https://img3.idealista.com/blur/WEB_LISTING/0/...          73056985
# 6513  https://img3.idealista.com/blur/WEB_LISTING/0/...             MAYOR
# 6514  https://img3.idealista.com/blur/WEB_LISTING/0/...             MAYOR
#
#       numPhotos floor      price  ... has3DTour has360  hasStaging  \
# 0            48    bj   335000.0  ...     False  False        True
# 1            57     2  1650000.0  ...     False   True        True
# 2            26   NaN   770000.0  ...     False  False       False
# 3            36     1   175000.0  ...     False  False       False
# 4            46     2   280000.0  ...     False  False       False
# ...         ...   ...        ...  ...       ...    ...         ...
# 6510         27     1  2500000.0  ...     False  False       False
# 6511         22    bj    79000.0  ...     False  False       False
# 6512         13   NaN   126800.0  ...     False  False       False
# 6513         14   NaN   126100.0  ...     False  False       False
# 6514         14   NaN   126100.0  ...     False  False       False
#
#                               highlight  superTopHighlight  topNewDevelopment  \
# 0     {'groupDescription': 'Destacado'}              False              False
# 1     {'groupDescription': 'Destacado'}              False              False
# 2     {'groupDescription': 'Destacado'}              False              False
# 3     {'groupDescription': 'Destacado'}              False              False
# 4     {'groupDescription': 'Destacado'}              False              False
# ...                                 ...                ...                ...
# 6510                                NaN              False              False
# 6511                                NaN              False              False
# 6512                                NaN              False              False
# 6513                                NaN              False              False
# 6514                                NaN              False              False
#
#      index                     neighborhood  \
# 0      NaN                              NaN
# 1      NaN                              NaN
# 2      NaN                              NaN
# 3      NaN                              NaN
# 4      NaN                              NaN
# ...    ...                              ...
# 6510  20.0                       Castellana
# 6511  21.0  Ensanche de Vallecas - La Gavia
# 6512  22.0                              NaN
# 6513  23.0                              NaN
# 6514  24.0                              NaN
#
#                                         labels newDevelopmentFinished
# 0                                          NaN                    NaN
# 1                                          NaN                    NaN
# 2                                          NaN                    NaN
# 3                                          NaN                    NaN
# 4                                          NaN                    NaN
# ...                                        ...                    ...
# 6510  [{'name': 'luxuryType', 'text': 'Lujo'}]                    NaN
# 6511                                       NaN                    NaN
# 6512                                       NaN                    NaN
# 6513                                       NaN                    NaN
# 6514                                       NaN                    NaN
#
# [6515 rows x 46 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0.3', 'Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0',
#        'propertyCode', 'thumbnail', 'externalReference', 'numPhotos', 'floor',
#        'price', 'propertyType', 'operation', 'size', 'exterior', 'rooms',
#        'bathrooms', 'address', 'province', 'municipality', 'district',
#        'country', 'latitude', 'longitude', 'showAddress', 'url', 'distance',
#        'description', 'hasVideo', 'status', 'newDevelopment', 'hasLift',
#        'parkingSpace', 'priceByArea', 'detailedType', 'suggestedTexts',
#        'hasPlan', 'has3DTour', 'has360', 'hasStaging', 'highlight',
#        'superTopHighlight', 'topNewDevelopment', 'index', 'neighborhood',
#        'labels', 'newDevelopmentFinished'],
#       dtype='object')

# %%
df = df[['price', 'propertyType', 'size', 'exterior', 'rooms',
         'bathrooms', 'address', 'province', 'municipality',
         'latitude', 'longitude', 'status', 'newDevelopment', 'hasLift',
         'parkingSpace', 'priceByArea', 'detailedType', 'highlight']]

# %% [markdown]
# # Missing Values

# %%
df.isnull().sum()
# Out:
# numPhotos            0
# price                0
# propertyType         0
# size                 0
# exterior          1948
# rooms                0
# bathrooms            0
# address              0
# province             0
# municipality         0
# latitude             0
# longitude            0
# status               0
# newDevelopment       0
# hasLift           1777
# parkingSpace      3992
# priceByArea          0
# detailedType         0
# highlight         3980
# dtype: int64

# %%
# Exterior cleaned
df['exterior'] = df['exterior'].fillna(False)
# Out:
# /var/folders/xs/s4fj4wdx6f7fkjpgcmjzz2lc0000gn/T/ipykernel_9453/1317668624.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['exterior'] = df['exterior'].fillna(False)

# %%
# hasLift cleaned
df['hasLift'] = df['hasLift'].fillna(False)
# Out:
# /var/folders/xs/s4fj4wdx6f7fkjpgcmjzz2lc0000gn/T/ipykernel_9453/538161793.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hasLift'] = df['hasLift'].fillna(False)

# %%
# highlight cleaned
df['highlight'] = df['highlight'].fillna(False)
# Out:
# /var/folders/xs/s4fj4wdx6f7fkjpgcmjzz2lc0000gn/T/ipykernel_9453/1096648325.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['highlight'] = df['highlight'].fillna(False)

# %%
# import numpy as np
# np.where(df['parkingSpace'].isnull(), )

# %%
df['parkingSpace'] = df['parkingSpace'].fillna("{'hasParkingSpace': False, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': None}")
# Out:
# /var/folders/xs/s4fj4wdx6f7fkjpgcmjzz2lc0000gn/T/ipykernel_9453/2321609946.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['parkingSpace'] = df['parkingSpace'].fillna("{'hasParkingSpace': False, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': None}")

# %%
df[df['parkingSpace'] == "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True}"]['parkingSpace'] = "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True, 'parkingSpacePrice': None}"
# Out:
# /var/folders/xs/s4fj4wdx6f7fkjpgcmjzz2lc0000gn/T/ipykernel_9453/1014684955.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['parkingSpace'] == "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True}"]['parkingSpace'] = "deez"

# %%
df['parkingSpace'] = df['parkingSpace'].apply(lambda x: "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True, 'parkingSpacePrice': None}" if x == "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True}" else x)

# %%
df['parkingSpace'].unique()
# Out:
# array(["{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True, 'parkingSpacePrice': None}",
#        "{'hasParkingSpace': False, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': None}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 25000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 20000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 2000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 90000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 7500.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 60000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 5000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 37000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 17850.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 80000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 30000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 29000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 10000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 65000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 95000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 21000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 50000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 7000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 75.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 16000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 19000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 1.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 40000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 20.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 12000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 80.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 14000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 23000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 55000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 38000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 28000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 85000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 7250.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 29800.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 24000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 15000.0}"],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# price             0
# propertyType      0
# size              0
# exterior          0
# rooms             0
# bathrooms         0
# address           0
# province          0
# municipality      0
# latitude          0
# longitude         0
# status            0
# newDevelopment    0
# hasLift           0
# parkingSpace      0
# priceByArea       0
# detailedType      0
# highlight         0
# dtype: int64

# %%
df.to_csv('cleaned_df.csv')
