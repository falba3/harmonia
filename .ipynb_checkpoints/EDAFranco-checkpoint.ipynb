# %%
import pandas as pd

# %%
df = pd.read_csv('new/full.csv')
df
# Out:
#       Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  propertyCode  \
# 0                0           0.0           0.0           0     100610812
# 1                1           1.0           1.0           1     101766825
# 2                2           2.0           2.0           2      98058039
# 3                3           3.0           3.0           3     102450094
# 4                4           4.0           4.0           4     100528636
# ...            ...           ...           ...         ...           ...
# 6510           195           NaN           NaN         195     101494299
# 6511           196           NaN           NaN         196     102878198
# 6512           197           NaN           NaN         197      97684223
# 6513           198           NaN           NaN         198     102620357
# 6514           199           NaN           NaN         199     100726970
#
#                                               thumbnail externalReference  \
# 0     https://img3.idealista.com/blur/WEB_LISTING/0/...              5644
# 1     https://img3.idealista.com/blur/WEB_LISTING/0/...          ACP1219A
# 2     https://img3.idealista.com/blur/WEB_LISTING/0/...          W-02OZM3
# 3     https://img3.idealista.com/blur/WEB_LISTING/0/...           nm00895
# 4     https://img3.idealista.com/blur/WEB_LISTING/0/...        3385-04514
# ...                                                 ...               ...
# 6510  https://img3.idealista.com/blur/WEB_LISTING/0/...          W-02SDQA
# 6511  https://img3.idealista.com/blur/WEB_LISTING/0/...               NaN
# 6512  https://img3.idealista.com/blur/WEB_LISTING/0/...          73056985
# 6513  https://img3.idealista.com/blur/WEB_LISTING/0/...             MAYOR
# 6514  https://img3.idealista.com/blur/WEB_LISTING/0/...             MAYOR
#
#       numPhotos floor      price  ... has3DTour has360  hasStaging  \
# 0            48    bj   335000.0  ...     False  False        True
# 1            57     2  1650000.0  ...     False   True        True
# 2            26   NaN   770000.0  ...     False  False       False
# 3            36     1   175000.0  ...     False  False       False
# 4            46     2   280000.0  ...     False  False       False
# ...         ...   ...        ...  ...       ...    ...         ...
# 6510         27     1  2500000.0  ...     False  False       False
# 6511         22    bj    79000.0  ...     False  False       False
# 6512         13   NaN   126800.0  ...     False  False       False
# 6513         14   NaN   126100.0  ...     False  False       False
# 6514         14   NaN   126100.0  ...     False  False       False
#
#                               highlight  superTopHighlight  topNewDevelopment  \
# 0     {'groupDescription': 'Destacado'}              False              False
# 1     {'groupDescription': 'Destacado'}              False              False
# 2     {'groupDescription': 'Destacado'}              False              False
# 3     {'groupDescription': 'Destacado'}              False              False
# 4     {'groupDescription': 'Destacado'}              False              False
# ...                                 ...                ...                ...
# 6510                                NaN              False              False
# 6511                                NaN              False              False
# 6512                                NaN              False              False
# 6513                                NaN              False              False
# 6514                                NaN              False              False
#
#      index                     neighborhood  \
# 0      NaN                              NaN
# 1      NaN                              NaN
# 2      NaN                              NaN
# 3      NaN                              NaN
# 4      NaN                              NaN
# ...    ...                              ...
# 6510  20.0                       Castellana
# 6511  21.0  Ensanche de Vallecas - La Gavia
# 6512  22.0                              NaN
# 6513  23.0                              NaN
# 6514  24.0                              NaN
#
#                                         labels newDevelopmentFinished
# 0                                          NaN                    NaN
# 1                                          NaN                    NaN
# 2                                          NaN                    NaN
# 3                                          NaN                    NaN
# 4                                          NaN                    NaN
# ...                                        ...                    ...
# 6510  [{'name': 'luxuryType', 'text': 'Lujo'}]                    NaN
# 6511                                       NaN                    NaN
# 6512                                       NaN                    NaN
# 6513                                       NaN                    NaN
# 6514                                       NaN                    NaN
#
# [6515 rows x 46 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0.3', 'Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0',
#        'propertyCode', 'thumbnail', 'externalReference', 'numPhotos', 'floor',
#        'price', 'propertyType', 'operation', 'size', 'exterior', 'rooms',
#        'bathrooms', 'address', 'province', 'municipality', 'district',
#        'country', 'latitude', 'longitude', 'showAddress', 'url', 'distance',
#        'description', 'hasVideo', 'status', 'newDevelopment', 'hasLift',
#        'parkingSpace', 'priceByArea', 'detailedType', 'suggestedTexts',
#        'hasPlan', 'has3DTour', 'has360', 'hasStaging', 'highlight',
#        'superTopHighlight', 'topNewDevelopment', 'index', 'neighborhood',
#        'labels', 'newDevelopmentFinished'],
#       dtype='object')

# %%
df = df[['numPhotos',
    'price', 'propertyType', 'size', 'exterior', 'rooms',
    'bathrooms', 'address', 'province', 'municipality',
    'latitude', 'longitude', 'status', 'newDevelopment', 'hasLift',
    'parkingSpace', 'priceByArea', 'detailedType', 'highlight']]

# %% [markdown]
# # Missing Values

# %%
df.isnull().sum()
# Out:
# numPhotos            0
# price                0
# propertyType         0
# size                 0
# exterior             0
# rooms                0
# bathrooms            0
# address              0
# province             0
# municipality         0
# latitude             0
# longitude            0
# status               0
# newDevelopment       0
# hasLift              0
# parkingSpace      3992
# priceByArea          0
# detailedType         0
# highlight         3980
# dtype: int64

# %%
df['exterior'] = df['exterior'].fillna(False)
# Out:
# /var/folders/xs/s4fj4wdx6f7fkjpgcmjzz2lc0000gn/T/ipykernel_26733/2464059507.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['exterior'] = df['exterior'].fillna(False)

# %%
df['hasLift'] = df['hasLift'].fillna(False)

# %%
df['parkingSpace']
# Out:
# array(["{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': True}",
#        nan,
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 25000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 20000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 2000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 90000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 7500.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 60000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 5000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 37000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 17850.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 80000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 30000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 29000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 10000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 65000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 95000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 21000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 50000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 7000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 75.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 16000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 19000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 1.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 40000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 20.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 12000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 80.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 14000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 23000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 55000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 38000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 28000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 85000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 7250.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 29800.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 24000.0}",
#        "{'hasParkingSpace': True, 'isParkingSpaceIncludedInPrice': False, 'parkingSpacePrice': 15000.0}"],
#       dtype=object)

# %%
# fillna(False)

# %%
# df['highlight'].unique() -> to false
# Out:
# array(["{'groupDescription': 'Destacado'}", nan,
#        "{'groupDescription': 'Top'}"], dtype=object)

# %%
df['neighborhood'].unique()
# Out:
# array([nan, 'San Pascual', 'Bellas Vistas', 'Villaverde Alto',
#        'Nuevos Ministerios-Ríos Rosas', 'Sol', 'Palomeras sureste',
#        'Numancia', 'Casco Antiguo', 'Nueva España', 'Recoletos',
#        'Pueblo Nuevo', 'Pradolongo', 'Zarzaquemada', 'Ventilla-Almenara',
#        'San Cristóbal', 'Simancas', 'Casco Histórico de Vallecas',
#        'Puerta del Ángel', 'Ventas', 'Berruguete', 'Vista Alegre',
#        'Buena Vista', 'Amposta', 'Entrevías', 'Ambroz',
#        'Casco Histórico de Vicálvaro', '12 de Octubre-Orcasur',
#        'Castellana', 'Imperial', 'Castilla', 'Goya', 'San Diego',
#        'Puerta Bonita', 'Peñagrande', 'Lista', 'Trafalgar',
#        'San Juan Bautista', 'Niño Jesús', 'Malasaña-Universidad',
#        'Zona Renfe', 'Cuatro Caminos', 'Chueca-Justicia', 'Aravaca',
#        'Prosperidad', 'Prado de Santo Domingo', 'Vallehermoso',
#        'Argüelles', 'San Fermín', 'Palomeras Bajas', 'Vírgenes',
#        'Palomas', 'Apóstol Santiago', 'Huertas-Cortes',
#        'Conde Orgaz-Piovera', 'Ciudad Jardín', 'San Isidro', 'Quintana',
#        'Gaztambide', 'Cuzco-Castillejos', 'Acacias', 'Valdeacederas',
#        'Valdezarza', 'Comillas', 'Fuentelarreina', 'Pilar', 'Guindalera',
#        'Opañel', 'Chopera', 'Club de Golf', 'Las Tablas',
#        'El Pinar- Punta Galea', 'Pacífico', 'El Viso',
#        'Lavapiés-Embajadores', 'Rejas', 'Almagro', 'Moscardó',
#        'Valdebebas - Valdefuentes', 'Ibiza', 'Vinateros', 'Delicias',
#        'Canillas', 'Pinar del Rey', 'Canillejas', 'Zona Pueblo',
#        'Zona Estación', 'Los Ángeles', 'Bernabéu-Hispanoamérica',
#        'Portazgo', 'Fontarrón', 'Alameda de Osuna', 'Campamento',
#        'Montealina', 'Ensanche de Vallecas - La Gavia', 'Palacio',
#        'Concepción', 'El Peñalar - Arroyo de Trofas - Montealegre',
#        'Fuente del Berro', 'Tres Olivos - Valverde', 'Jerónimos',
#        'Ciudad Universitaria', 'Prado de Somosaguas', 'Arapiles',
#        'Batallas', 'Monte Rozas', 'Lucero', 'Parque Ondarreta - Urtinsa',
#        'Las Matas- Peñascales', 'Parque Lisboa - La Paz', 'Costillares',
#        'Aluche', 'Casco Histórico de Barajas',
#        'Virgen del Cortijo - Manoteras', 'Butarque', 'El Cantizal',
#        'Somosaguas', 'El Caño- Maracaibo', 'Arcos', 'Adelfas', 'Abrantes',
#        'Zona Centro Joven', 'Sanchinarro', 'Montecillo', 'Los Rosales',
#        'Parque Mayor', 'Los Cármenes', 'Casa de Campo',
#        'Parque oeste - Fuente Cisneros', 'El Cañaveral', 'El Pardo',
#        'Mirasierra', 'Arroyo del Fresno', 'Colina', 'La Cañadilla',
#        'Las Dehesillas-Vereda de los Estudiantes', 'El Carrascal',
#        'Valdebernardo - Valderrivas', 'Almendrales', 'Zona norte',
#        'Valderas - Los Castillos', 'La Paz', 'Estrella', 'Timón',
#        'Palos de Moguer', 'Santa Eugenia', 'Pavones', 'El Plantío',
#        'Valdepelayo-Montepinos-Arroyo Culebro', 'Europolis',
#        'Leganés norte', 'San Nicasio', 'Rosas', 'La Fortuna', 'Horcajo',
#        'Valdemarín', 'Atalaya', 'Zofío', 'Montecarmelo',
#        'Salud y Alegría - El Lago', 'El Burgo',
#        'Descubridores-Escritores', 'Molino de la Hoz',
#        'Campodón - Ventorro del Cano', 'Zona Avenida Europa',
#        'Marazuela- El Torreón', 'Águilas', 'Derechos Humanos'],
#       dtype=object)

# %%
df['municipality'].unique()
# Out:
# array(['Rivas-Vaciamadrid', 'Madrid', 'Alcalá de Henares', 'Yebes',
#        'Torrelodones', 'Tres Cantos', 'Robledo de Chavela', 'Alovera',
#        'Camarma de Esteruelas', 'San Sebastián de los Reyes',
#        'Numancia de la Sagra', 'Fuenlabrada', 'Hoyo de Manzanares',
#        'Ugena', 'Móstoles', 'Olias del Rey', 'Horche',
#        'Chozas de Canales', 'San Lorenzo de El Escorial',
#        'Villaviciosa de Odón', 'Arganda', 'Yepes', 'Ciruelos', 'Noblejas',
#        'Ocaña', 'Cabanillas del Campo', 'Humanes de Madrid', 'Yeles',
#        'Galapagar', 'Torrejón de Ardoz', 'Cabanillas de la Sierra',
#        'Las Rozas de Madrid', 'Arroyomolinos', 'Navalcarnero',
#        'Cercedilla', 'Coslada', 'Cedillo del Condado',
#        'Casarrubios del Monte', 'Ciempozuelos', 'Driebes', 'Carranque',
#        'El Viso de San Juan', 'Fuensalida', 'Collado Villalba',
#        'Guadalajara', 'Mejorada del Campo', 'Leganés',
#        'Serranillos del Valle', 'Villarejo de Salvanés', 'Parla',
#        'Casarrubuelos', 'Arcicollar', 'Alcorcón', 'El Álamo',
#        'Campo Real', 'Magán', 'Valdemoro', 'Valdeolmos-Alalpardo',
#        'Morata de Tajuña', 'Valdemorillo', 'Los Molinos', 'Aranjuez',
#        'Lozoyuela-Navas-Sieteiglesias', 'Escariche', 'Pinto', 'Illescas',
#        'El Casar', 'Pioz', 'Torres de la Alameda',
#        'Miraflores de la Sierra', 'Aldea del Fresno',
#        'Villanueva de Perales', 'Villanueva de la Cañada',
#        'Fuentidueña de Tajo', 'Marchamalo', 'San Martín de Valdeiglesias',
#        'Paracuellos de Jarama', 'Valdetorres de Jarama', 'Hontoba',
#        'La Moraleja', 'Galápagos', 'Santa Cruz del Retamar',
#        'Moralzarzal', 'Pedrezuela', 'Boadilla del Monte',
#        'Torrejón del Rey', 'Esquivias', 'Yuncler', 'Eurovillas',
#        'Villaseca de la Sagra', 'Mondéjar', 'El Espinar',
#        'Colmenar Viejo', 'Villalbilla', 'Ontigola', 'Manzanares el Real',
#        'Alcobendas', 'Yuncos', 'Getafe', 'Velilla de San Antonio',
#        'Añover de Tajo', 'Colmenar del Arroyo', 'Pinilla del Valle',
#        'Tortola de Henares', 'Camarena', 'Majadahonda', 'Palomeque',
#        'Fresnedillas de la Oliva', 'Algete', 'Meco', 'Malaga del Fresno',
#        'Torrelaguna', 'San Ildefonso o la Granja', 'Colmenar de Oreja',
#        'San Fernando de Henares', 'Moraleja de Enmedio',
#        'Perales de Tajuña', 'Santo Domingo', 'El Escorial', 'Recas',
#        'Navacerrada', 'Villa del Prado', 'Villaluenga de la Sagra',
#        'Becerril de la Sierra', 'Carabaña', 'Talamanca de Jarama',
#        'Alameda de la Sagra', 'Mocejón', 'El Molar', 'Bargas',
#        'Fuentenovilla', 'Nuevo Baztan', 'Collado Mediano', 'Alpedrete',
#        'Colmenarejo', 'Pozuelo de Alarcón', 'Pozo de Guadalajara',
#        'Villamantilla', 'Seseña', 'Valmojado', 'San Martín de la Vega',
#        'El Vellón', 'Daganzo de Arriba', 'Valdeavero', 'Quijorna',
#        'Puerto del Rosario', 'Guadarrama', 'Griñón', 'Calalberche',
#        'Renera', 'Azuqueca de Henares', 'Loeches', 'Tielmes',
#        'Villamanta', 'Santa María de la Alameda',
#        'Villanueva del Pardillo', 'Cotos de Monterrey',
#        'Pelayos de la Presa', 'Chapineria', 'Fuente el Saz de Jarama',
#        'Villarrubia de Santiago', 'Valdemaqueda', 'Uceda', 'Bustarviejo',
#        'Fuente del Fresno', 'Sevilla la Nueva', 'Valdeaveruelo',
#        'Soto del Real', 'Las Ventas de Retamosa', 'Cerceda',
#        'Cubas de la Sagra', 'Las Navas del Marqués', 'Valdilecha',
#        'San Agustin de Guadalix', 'Fresno de Torote', 'Chinchón',
#        'Torrejón de Velasco', 'Méntrida', 'Club de Campo', 'Lominchar',
#        'Camarenilla', 'Otero de Herreros', 'Belmonte de Tajo',
#        'Vegas de Matute', 'Valdaracete', 'Olmeda de las Fuentes',
#        'Casa de Uceda', 'Gargantilla del Lozoya', 'Brunete',
#        'Robledillo de Mohernando', 'Revenga', 'Palazuelos de Eresma',
#        'El Boalo', 'Yunquera de Henares', 'Valdelagua', 'Venturada',
#        'Cabañas de Yepes', 'Illana', 'Villasequilla', 'Navas del Rey',
#        'Torrejón de la Calzada', 'Pezuela de las Torres',
#        'Guadalix de la Sierra', 'Villamiel de Toledo', 'Pantoja'],
#       dtype=object)
