# %%
import pandas as pd
import os

# %%
df = pd.read_csv('new/full.csv')
df.head()
# Out:
#    Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  propertyCode  \
# 0             0           0.0           0.0           0     100610812
# 1             1           1.0           1.0           1     101766825
# 2             2           2.0           2.0           2      98058039
# 3             3           3.0           3.0           3     102450094
# 4             4           4.0           4.0           4     100528636
#
#                                            thumbnail externalReference  \
# 0  https://img3.idealista.com/blur/WEB_LISTING/0/...              5644
# 1  https://img3.idealista.com/blur/WEB_LISTING/0/...          ACP1219A
# 2  https://img3.idealista.com/blur/WEB_LISTING/0/...          W-02OZM3
# 3  https://img3.idealista.com/blur/WEB_LISTING/0/...           nm00895
# 4  https://img3.idealista.com/blur/WEB_LISTING/0/...        3385-04514
#
#    numPhotos floor      price  ... has3DTour has360  hasStaging  \
# 0         48    bj   335000.0  ...     False  False        True
# 1         57     2  1650000.0  ...     False   True        True
# 2         26   NaN   770000.0  ...     False  False       False
# 3         36     1   175000.0  ...     False  False       False
# 4         46     2   280000.0  ...     False  False       False
#
#                            highlight  superTopHighlight  topNewDevelopment  \
# 0  {'groupDescription': 'Destacado'}              False              False
# 1  {'groupDescription': 'Destacado'}              False              False
# 2  {'groupDescription': 'Destacado'}              False              False
# 3  {'groupDescription': 'Destacado'}              False              False
# 4  {'groupDescription': 'Destacado'}              False              False
#
#   index neighborhood labels newDevelopmentFinished
# 0   NaN          NaN    NaN                    NaN
# 1   NaN          NaN    NaN                    NaN
# 2   NaN          NaN    NaN                    NaN
# 3   NaN          NaN    NaN                    NaN
# 4   NaN          NaN    NaN                    NaN
#
# [5 rows x 46 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0.3', 'Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0',
#        'propertyCode', 'thumbnail', 'externalReference', 'numPhotos', 'floor',
#        'price', 'propertyType', 'operation', 'size', 'exterior', 'rooms',
#        'bathrooms', 'address', 'province', 'municipality', 'district',
#        'country', 'latitude', 'longitude', 'showAddress', 'url', 'distance',
#        'description', 'hasVideo', 'status', 'newDevelopment', 'hasLift',
#        'parkingSpace', 'priceByArea', 'detailedType', 'suggestedTexts',
#        'hasPlan', 'has3DTour', 'has360', 'hasStaging', 'highlight',
#        'superTopHighlight', 'topNewDevelopment', 'index', 'neighborhood',
#        'labels', 'newDevelopmentFinished'],
#       dtype='object')

# %%
df = df[['propertyCode', 'thumbnail', 'externalReference', 'numPhotos', 'floor',
       'price', 'propertyType', 'operation', 'size', 'exterior', 'rooms',
       'bathrooms', 'address', 'province', 'municipality', 'district',
       'country', 'latitude', 'longitude', 'showAddress', 'url', 'distance',
       'description', 'hasVideo', 'status', 'newDevelopment', 'hasLift',
       'parkingSpace', 'priceByArea', 'detailedType', 'suggestedTexts',
       'hasPlan', 'has3DTour', 'has360', 'hasStaging', 'highlight',
       'superTopHighlight', 'topNewDevelopment', 'index', 'neighborhood',
       'labels', 'newDevelopmentFinished']]

# %%
df.isnull().sum()
# Out:
# propertyCode                 0
# thumbnail                   78
# externalReference         1437
# numPhotos                    0
# floor                     2156
# price                        0
# propertyType                 0
# operation                    0
# size                         0
# exterior                  1948
# rooms                        0
# bathrooms                    0
# address                      0
# province                     0
# municipality                 0
# district                  1498
# country                      0
# latitude                     0
# longitude                    0
# showAddress                  0
# url                          0
# distance                     0
# description                 10
# hasVideo                     0
# status                       0
# newDevelopment               0
# hasLift                   1777
# parkingSpace              3992
# priceByArea                  0
# detailedType                 0
# suggestedTexts               0
# hasPlan                      0
# has3DTour                    0
# has360                       0
# hasStaging                   0
# highlight                 3980
# superTopHighlight            0
# topNewDevelopment            0
# index                       50
# neighborhood              3396
# labels                    6032
# newDevelopmentFinished    6490
# dtype: int64

# %%
# Complete columns
df[['propertyCode', 'price', 'propertyType', 'size', 'rooms',
    'bathrooms', 'address', 'province', 'municipality', 'status',
    'newDevelopment', 'hasLift', 'priceByArea', 'detailedType',
    'hasPlan', 'topNewDevelopment']]
# Out:
#       propertyCode      price propertyType   size  rooms  bathrooms  \
# 0        100610812   335000.0         flat  136.0      3          2
# 1        101766825  1650000.0         flat  179.0      2          3
# 2         98058039   770000.0         flat  109.0      2          2
# 3        102450094   175000.0         flat   49.0      1          1
# 4        100528636   280000.0         flat  121.0      4          2
# ...            ...        ...          ...    ...    ...        ...
# 6510     101494299  2500000.0         flat  341.0      4          2
# 6511     102878198    79000.0         flat   66.0      1          1
# 6512      97684223   126800.0       chalet  159.0      3          3
# 6513     102620357   126100.0       chalet  150.0      3          2
# 6514     100726970   126100.0       chalet  150.0      3          3
#
#                               address province           municipality status  \
# 0                              SIGRID   Madrid      Rivas-Vaciamadrid   good
# 1       Calle del Príncipe de Vergara   Madrid                 Madrid   good
# 2                        barrio Ibiza   Madrid                 Madrid   good
# 3            Calle de los Morales, 10   Madrid                 Madrid   good
# 4                  Calle del Río Ulla   Madrid                 Madrid   good
# ...                               ...      ...                    ...    ...
# 6510                barrio Castellana   Madrid                 Madrid   good
# 6511   Calle de José Gutiérrez Maroto   Madrid                 Madrid   good
# 6512  Calle del Pintor Álvaro Delgado   Madrid  Olmeda de las Fuentes   good
# 6513                            MAYOR   Madrid  Olmeda de las Fuentes   good
# 6514                            MAYOR   Madrid  Olmeda de las Fuentes   good
#
#       newDevelopment hasLift  priceByArea  \
# 0              False    True       2463.0
# 1              False    True       9218.0
# 2              False    True       7064.0
# 3              False    True       3571.0
# 4              False   False       2314.0
# ...              ...     ...          ...
# 6510           False    True       7331.0
# 6511           False    True       1197.0
# 6512           False     NaN        797.0
# 6513           False     NaN        841.0
# 6514           False     NaN        841.0
#
#                                            detailedType  hasPlan  \
# 0                                  {'typology': 'flat'}     True
# 1                                  {'typology': 'flat'}     True
# 2                                  {'typology': 'flat'}    False
# 3                                  {'typology': 'flat'}     True
# 4                                  {'typology': 'flat'}     True
# ...                                                 ...      ...
# 6510                               {'typology': 'flat'}     True
# 6511                               {'typology': 'flat'}     True
# 6512  {'typology': 'chalet', 'subTypology': 'terrace...    False
# 6513  {'typology': 'chalet', 'subTypology': 'terrace...    False
# 6514  {'typology': 'chalet', 'subTypology': 'terrace...    False
#
#       topNewDevelopment
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 6510              False
# 6511              False
# 6512              False
# 6513              False
# 6514              False
#
# [6515 rows x 16 columns]

# %%
df = df[['propertyCode', 'price', 'propertyType', 'size', 'rooms',
    'bathrooms', 'address', 'province', 'municipality', 'status',
    'newDevelopment', 'hasLift', 'priceByArea', 'detailedType',
    'hasPlan', 'topNewDevelopment']]

# %%
df.isnull().sum()
# Out:
# propertyCode            0
# price                   0
# propertyType            0
# size                    0
# rooms                   0
# bathrooms               0
# address                 0
# province                0
# municipality            0
# status                  0
# newDevelopment          0
# hasLift              1777
# priceByArea             0
# detailedType            0
# hasPlan                 0
# topNewDevelopment       0
# dtype: int64
