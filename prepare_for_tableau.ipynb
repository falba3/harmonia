# %%
import pandas as pd

# %%
df = pd.read_csv('recleaned_df.csv')

# %%
df.columns
# Out:
# Index(['price', 'propertyType', 'size', 'exterior', 'rooms', 'bathrooms',
#        'address', 'province', 'municipality', 'latitude', 'longitude',
#        'status', 'newDevelopment', 'hasLift', 'priceByArea', 'hasParkingSpace',
#        'isParkingSpaceIncludedInPrice', 'parkingSpacePrice',
#        'groupDescription', 'typology', 'subTypology'],
#       dtype='object')

# %%
df['province'].unique()
# Out:
# array(['Madrid', 'Guadalajara', 'Toledo', 'Segovia', 'Las Palmas',
#        'Ávila'], dtype=object)

# %%
df['municipality'].nunique()
# Out:
# 205

# %%
df = df[df['province'] == 'Madrid']

# %%
df
# Out:
#            price propertyType   size  exterior  rooms  bathrooms  \
# 0       295000.0         flat   67.0      True      1          1
# 1       710000.0       chalet  172.0     False      2          2
# 2       800000.0         flat  101.0      True      2          2
# 3       995000.0         flat  190.0      True      3          2
# 4      1020000.0         flat  177.0      True      3          2
# ...          ...          ...    ...       ...    ...        ...
# 14700   830000.0         flat  175.0      True      5          4
# 14701   889000.0         flat  118.0      True      2          2
# 14702  4200000.0         flat  471.0      True      6          5
# 14703  1050000.0       duplex  233.0      True      3          4
# 14704   919000.0         flat  112.0     False      3          3
#
#                                     address province municipality   latitude  \
# 0                    Calle de los Misterios   Madrid       Madrid  40.441226
# ...
